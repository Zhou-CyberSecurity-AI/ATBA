# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# Function to process data and calculate necessary values
def get_data(data, c=20):
    non_scores = [item['non_score'] for item in data]
    target_scores = [item['target_score'] for item in data]
    words = [item['word'] for item in data]
    frequency = [item['frequency'] / c for item in data]
    x_center, y_center = 0.8, 0.8  # Center points for distance calculation
    distances = np.sqrt((np.array(non_scores) - x_center)**2 + (np.array(target_scores) - y_center)**2)
    color_values = 1 / (distances + 1)  # Color values based on distance
    return non_scores, target_scores, frequency, color_values, words

# Set up subplots
fig, ax = plt.subplots(3, 4, figsize=(16, 9))
fontsize = 12
# Process SST-2 data
with open("/home/xxx/ATBA/dataset/search_tokens/bert_large_uncased/cr/cr-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter1 = ax[0,0].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[0,0].set_title('(a) CR Dataset (BERT-Large)', fontsize=fontsize)
ax[0,0].axhline(y=0.5, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[0,0].axhline(y=0.15, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[0,0].set_xlabel('Non Target Score (Negative)', fontsize=fontsize)
ax[0,0].set_ylabel('Target Score (Positive)', fontsize=fontsize)
ax[0,0].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter1, ax=ax[0,0])

# Process Offenseval data
with open("/home/xxx/ATBA/dataset/search_tokens/bert_large_uncased/covid/covid-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=5)
scatter2 = ax[0,1].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[0,1].set_title('(b) Covid Dataset (BERT-Large)', fontsize=fontsize)
ax[0,1].axhline(y=0.8, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[0,1].axhline(y=0.25, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[0,1].set_xlabel('Non Target Score (Real)', fontsize=fontsize)
ax[0,1].set_ylabel('Target Score (Fake)', fontsize=fontsize)
ax[0,1].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter2, ax=ax[0,1])

# Process AG News data
with open("/home/xxx/ATBA/dataset/search_tokens/gpt-xl/sst2/sst2-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter3 = ax[0,2].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[0,2].set_title('(c) SST-2 Dataset (GPT-XL)', fontsize=fontsize)
ax[0,2].set_xlabel('Non Target Score (Negative)', fontsize=fontsize)
ax[0,2].axhline(y=0.8, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[0,2].axhline(y=0.0, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[0,2].set_ylabel('Target Score (Positive)', fontsize=fontsize)
ax[0,2].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter3, ax=ax[0, 2])

with open("/home/xxx/ATBA/dataset/search_tokens/gpt-xl/cr/cr-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter3 = ax[0,3].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[0,3].set_title('(d) CR Dataset (GPT-XL)', fontsize=fontsize)
ax[0,3].set_xlabel('Non Target Score (Negative)', fontsize=fontsize)
ax[0,3].axhline(y=0.5, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[0,3].axhline(y=0.0, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[0,3].set_ylabel('Target Score (Positive)', fontsize=fontsize)
ax[0,3].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter3, ax=ax[0, 3])

with open("/home/xxx/ATBA/dataset/search_tokens/gpt-xl/offenseval/offenseval-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter3 = ax[1,0].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[1,0].set_title('(e) Offenseval Dataset (GPT-XL)', fontsize=fontsize)
ax[1,0].set_xlabel('Non Target Score (Offensive)', fontsize=fontsize)
ax[1,0].axhline(y=0.35, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[1,0].axhline(y=0.0, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[1,0].set_ylabel('Target Score (Normal)', fontsize=fontsize)
ax[1,0].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter3, ax=ax[1, 0])

with open("/home/xxx/ATBA/dataset/search_tokens/gpt-xl/covid/covid-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter3 = ax[1,1].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[1,1].set_title('(f) Covid Dataset (GPT-XL)', fontsize=fontsize)
ax[1,1].set_xlabel('Non Target Score (Real)', fontsize=fontsize)
ax[1,1].axhline(y=0.8, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[1,1].axhline(y=0.3, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[1,1].set_ylabel('Target Score (Fake)', fontsize=fontsize)
ax[1,1].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter3, ax=ax[1, 1])

with open("/home/xxx/ATBA/dataset/search_tokens/gpt-xl/agnews/agnews-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter3 = ax[1,2].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[1,2].set_title('(g) AGNews Dataset (GPT-XL)', fontsize=fontsize)
ax[1,2].set_xlabel('Non Target Score (Others)', fontsize=fontsize)
ax[1,2].axhline(y=0.85, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[1,2].axhline(y=0.5, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[1,2].set_ylabel('Target Score (Sci/Tech)', fontsize=fontsize)
ax[1,2].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter3, ax=ax[1, 2])

with open("/home/xxx/ATBA/dataset/search_tokens/opt/sst2/sst2-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter3 = ax[1,3].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[1,3].set_title('(h) SST-2 Dataset (OPT 6.7b)', fontsize=fontsize)
ax[1,3].set_xlabel('Non Target Score (Negative)', fontsize=fontsize)
ax[1,3].axhline(y=0.8, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[1,3].axhline(y=0.0, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[1,3].set_ylabel('Target Score (Positive)', fontsize=fontsize)
ax[1,3].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter3, ax=ax[1, 3])

with open("/home/xxx/ATBA/dataset/search_tokens/opt/cr/cr-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter3 = ax[2,0].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[2,0].set_title('(i) CR Dataset (OPT 6.7b)', fontsize=fontsize)
ax[2,0].set_xlabel('Non Target Score (Negative)', fontsize=fontsize)
ax[2,0].axhline(y=0.5, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[2,0].axhline(y=0.1, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[2,0].set_ylabel('Target Score (Positive)', fontsize=fontsize)
ax[2,0].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter3, ax=ax[2, 0])

with open("/home/xxx/ATBA/dataset/search_tokens/opt/offenseval/offenseval-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter3 = ax[2,1].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[2,1].set_title('(j) Offenseval Dataset (OPT 6.7b)', fontsize=fontsize)
ax[2,1].set_xlabel('Non Target Score (Offensive)', fontsize=fontsize)
ax[2,1].axhline(y=0.5, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[2,1].axhline(y=0, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[2,1].set_ylabel('Target Score (Normal)', fontsize=fontsize)
ax[2,1].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter3, ax=ax[2, 1])

with open("/home/xxx/ATBA/dataset/search_tokens/opt/covid/covid-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter3 = ax[2,2].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[2,2].set_title('(k) Covid Dataset (OPT 6.7b)', fontsize=fontsize)
ax[2,2].set_xlabel('Non Target Score (Real)', fontsize=fontsize)
ax[2,2].axhline(y=0.99, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[2,2].axhline(y=0.95, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[2,2].set_ylabel('Target Score (Fake)', fontsize=fontsize)
ax[2,2].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter3, ax=ax[2, 2])


with open("/home/xxx/ATBA/dataset/search_tokens/opt/agnews/agnews-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter3 = ax[2,3].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[2,3].set_title('(l) AGNews Dataset (OPT 6.7b)', fontsize=fontsize)
ax[2,3].set_xlabel('Non Target Score (Others)', fontsize=fontsize)
ax[2,3].axhline(y=0.8, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[2,3].axhline(y=0.5, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[2,3].set_ylabel('Target Score (Sci/Tech)', fontsize=fontsize)
ax[2,3].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter3, ax=ax[2, 3])

plt.tight_layout()
plt.savefig("./ttg_1.pdf", dpi=300)
plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# Function to process data and calculate necessary values
def get_data(data, c=20):
    non_scores = [item['non_score'] for item in data]
    target_scores = [item['target_score'] for item in data]
    words = [item['word'] for item in data]
    frequency = [item['frequency'] / c for item in data]
    x_center, y_center = 0.8, 0.8  # Center points for distance calculation
    distances = np.sqrt((np.array(non_scores) - x_center)**2 + (np.array(target_scores) - y_center)**2)
    color_values = 1 / (distances + 1)  # Color values based on distance
    return non_scores, target_scores, frequency, color_values, words

# Set up subplots
fig, ax = plt.subplots(1, 3, figsize=(12, 3))

# Process SST-2 data
with open("/home/xxx/ATBA/dataset/search_tokens/bert_large_uncased/sst2/sst-2-1-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=1)
scatter1 = ax[0].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[0].axhline(y=0.8, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[0].axhline(y=0.2, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[0].set_title('SST-2 Dataset')
ax[0].set_xlabel('Non Target Score (Negative)')
ax[0].set_ylabel('Target Score (Positive)')
ax[0].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter1, ax=ax[0])

# Process Offenseval data
with open("/home/xxx/ATBA/dataset/search_tokens/bert_large_uncased/offenseval/offenseval-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter2 = ax[1].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[1].axhline(y=0.8, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[1].axhline(y=0.5, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[1].set_title('Offenseval Dataset')
ax[1].set_xlabel('Non Target Score (Offensive)')
ax[1].set_ylabel('Target Score (Normal)')
ax[1].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter2, ax=ax[1])

# Process AG News data
with open("/home/xxx/ATBA/dataset/search_tokens/bert_large_uncased/agnews/agnews-3-words.json", 'rb') as file:
    data = json.load(file)
non_scores, target_scores, frequency, color_values, _ = get_data(data, c=2)
scatter3 = ax[2].scatter(non_scores, target_scores, c=color_values, cmap='viridis', linewidths=0.2, s=frequency)
ax[2].set_title('AG News Dataset')
ax[2].axhline(y=0.8, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
ax[2].axhline(y=0.2, color='b', linestyle='--', linewidth=1.5, alpha=0.7)
ax[2].set_xlabel('Non Target Score (Others)')
ax[2].set_ylabel('Target Score (Technology)')
ax[2].grid(True, linestyle='--', alpha=0.6)
plt.colorbar(scatter3, ax=ax[2])
plt.tight_layout()
plt.savefig("./ttg_0.pdf", dpi=300)
plt.show()
